# %%
import pickle
from PIL import Image
from src import show_boxes

# %%
with open('./data.dat','rb') as f:
    data = pickle.load(f)

# %%
data['imgs']
# Out:
# ['./imgs/1.JPG',
#  './imgs/2.JPG',
#  './imgs/3.JPG',
#  './imgs/4.JPG',
#  './imgs/5.JPG',
#  './imgs/6.JPG',
#  './imgs/7.JPG',
#  './imgs/8.JPG',
#  './imgs/9.JPG',
#  './imgs/10.JPG']

# %%
show_boxes(Image.open(data['imgs'][7]), data['bounding_boxes'][7], 'yellow', 2)
# Out:
# <PIL.Image.Image image mode=RGB size=1440x1080 at 0x110E6D780>

# %%
show_boxes(Image.open(data['imgs'][8]), data['bounding_boxes'][8], 'yellow', 2)
# Out:
# <PIL.Image.Image image mode=RGB size=1440x1080 at 0x1276EABA8>
